# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("NYC").getOrCreate()

base_path = "/home/jovyan/work"

# %%
df_dailyAVG = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://postgres:5432/traffic") \
    .option("dbtable", "daily_AVG_weather_accidents") \
    .option("user", "admin") \
    .option("password", "admin") \
    .option("driver", "org.postgresql.Driver") \
    .load()

df_dailyAVG.show()
# Out:
# +----+-----+--------+----------------------+--------+
# |year|month|rain_day|avg_collisions_per_day|num_days|
# +----+-----+--------+----------------------+--------+
# |2023|    1|       0|     206.9090909090909|      11|
# |2023|    1|       1|                234.65|      20|
# |2023|    2|       0|              234.3125|      16|
# |2023|    2|       1|                 222.0|      12|
# |2023|    3|       0|    238.66666666666666|      15|
# |2023|    3|       1|               247.625|      16|
# |2023|    4|       0|                 230.7|      20|
# |2023|    4|       1|                 252.5|      10|
# |2023|    5|       0|                 268.5|      22|
# |2023|    5|       1|    250.55555555555554|       9|
# |2023|    6|       0|    249.57142857142858|      14|
# |2023|    6|       1|              256.5625|      16|
# |2023|    7|       0|              246.1875|      16|
# |2023|    7|       1|                 245.0|      15|
# |2023|    8|       0|     237.6153846153846|      13|
# |2023|    8|       1|    240.72222222222223|      18|
# |2023|    9|       0|     263.2857142857143|      14|
# |2023|    9|       1|              249.9375|      16|
# |2023|   10|       0|     259.8421052631579|      19|
# |2023|   10|       1|     258.5833333333333|      12|
# +----+-----+--------+----------------------+--------+
# only showing top 20 rows

# %%
df_hourlyWeather = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://postgres:5432/traffic") \
    .option("dbtable", "hourly_weather_accidents") \
    .option("user", "admin") \
    .option("password", "admin") \
    .option("driver", "org.postgresql.Driver") \
    .load()

df_hourlyWeather.show()
# Out:
# +-----------------+------------+----------------+-----------+-------------------+
# |weather_condition|weather_hour|total_collisions|total_hours|collisions_per_hour|
# +-----------------+------------+----------------+-----------+-------------------+
# |          No Rain|           0|           11937|       1125| 10.610666666666667|
# |             Rain|           0|            3620|        310|  11.67741935483871|
# |          No Rain|           1|            6249|       1115|  5.604484304932735|
# |             Rain|           1|            2054|        293|  7.010238907849829|
# |          No Rain|           2|            5223|       1158|  4.510362694300518|
# |             Rain|           2|            1358|        279|  4.867383512544803|
# |          No Rain|           3|            4706|       1148|  4.099303135888502|
# |             Rain|           3|            1465|        295|  4.966101694915254|
# |          No Rain|           4|            5189|       1120|  4.633035714285715|
# |             Rain|           4|            1866|        331|  5.637462235649547|
# |          No Rain|           5|            5385|       1147|   4.69485614646905|
# |             Rain|           5|            1796|        286|   6.27972027972028|
# |          No Rain|           6|            7312|       1159|  6.308886971527179|
# |             Rain|           6|            2263|        282|   8.02482269503546|
# |          No Rain|           7|            9913|       1137|  8.718557607739665|
# |             Rain|           7|            3120|        324|   9.62962962962963|
# |          No Rain|           8|           13948|       1130| 12.343362831858407|
# |             Rain|           8|            4076|        322| 12.658385093167702|
# |          No Rain|           9|           12388|       1150| 10.772173913043478|
# |             Rain|           9|            3483|        310| 11.235483870967743|
# +-----------------+------------+----------------+-----------+-------------------+
# only showing top 20 rows
